# %% [markdown]
# # Grammars and Sentence Parsing, and a Tagging Problem
# ## Noah Johnson

# %% [markdown]
# **Verify that the sentence "I shot an elephant in my pajamas." can be parsed two ways.**

# %%
import nltk

groucho_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")

sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
for tree in parser.parse(sent):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# We can see that two trees are made out of this sentence. The sentence is structurally ambiguous. The prepositional phrase "in my pajamas" can be included in the noun phrase or the verb phrase. This changes the meaning of the sentence. Either I shot an elephant which was residing inside my pajamas, or I shot an elephant while wearing my pajamas.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# **Confirm that the Groucho grammar thinks the following sentence is illegal: "I shot a lion in my pajamas."**

# %%
sent = ['I', 'shot', 'a', 'lion', 'in', 'my', 'pajamas']
try:
    for tree in parser.parse(sent):
        print(tree)
except Exception as e:
    print("ERROR: ", e)
# Out:
# ERROR:  Grammar does not cover some of the input words: "'a', 'lion'".

# %% [markdown]
# The sentence is illegal because the words 'a' and 'lion' are not in the vocabulary learned by the grammar, so the parser can't tag the words.

# %% [markdown]
# **Alter the grammar so that it allows this sentence.**

# %%
new_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my' | 'a'
N -> 'elephant' | 'pajamas' | 'lion'
V -> 'shot'
P -> 'in'
""")

sent = ['I', 'shot', 'a', 'lion', 'in', 'my', 'pajamas']
new_parser = nltk.ChartParser(new_grammar)
for tree in new_parser.parse(sent):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det a) (N lion)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det a) (N lion) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# I added the words 'lion' and 'a' to the new grammar, and now the sentence can be parsed.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# **Alter the grammar so that it allows this sentence: "I aimed at an elephant." This requires new vocabulary words, but it also requires a new kind of verb phrase.**

# %%
new_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP | V P NP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot' | 'aimed'
P -> 'in' | 'at'
""")

sent = ['I', 'aimed', 'at', 'an', 'elephant']
new_parser = nltk.ChartParser(new_grammar)
for tree in new_parser.parse(sent):
    print(tree)
# Out:
# (S (NP I) (VP (V aimed) (P at) (NP (Det an) (N elephant))))

# %% [markdown]
# The new verb phrase is of the form (Verb Preposition Noun-Phrase).

# %% [markdown]
# **Generate 10 possible sentences from this new grammar.**

# %%
from nltk.parse.generate import generate

for sentence in generate(new_grammar, n=10):
        print(' '.join(sentence))
# Out:
# an elephant shot an elephant
# an elephant shot an pajamas
# an elephant shot my elephant
# an elephant shot my pajamas
# an elephant shot an elephant in an elephant
# an elephant shot an elephant in an pajamas
# an elephant shot an elephant in my elephant
# an elephant shot an elephant in my pajamas
# an elephant shot an elephant in an elephant in an elephant
# an elephant shot an elephant in an elephant in an pajamas

# %% [markdown]
# ## Problem 3

# %% [markdown]
# **Make up a very different sentence that the grammar thinks is illegal; e.g., "I came, I saw, I conquered."**

# %% [markdown]
# After spending quite a while with a long sentence and failing, let's just pick a very simple sentence.
#
# "David please end this eternal nightmare."

# %%
# Showing illegality
twain_quote = """
David please end this eternal nightmare
""".split()

try:
    for tree in parser.parse(twain_quote):
        print(tree)
except Exception as e:
    print("ERROR: ", e)
# Out:
# ERROR:  Grammar does not cover some of the input words: "'David', 'please', 'end', 'this', 'eternal', 'nightmare'".

# %% [markdown]
# **Use the method of section 3.2 to write a grammar that will accept your sentence, and test it.**

# %%
twain_grammar_string = """
S -> NP VP
NP -> Det N | 'David'
VP -> Adv V | VP NP
Det -> 'this'
N -> 'nightmare' | Adj N
Adj -> 'eternal'
V -> 'end'
Adv -> 'please'
"""

with open('twain_grammar.cfg', 'w') as f:
    f.write(twain_grammar_string)

twain_grammar = nltk.data.load('file:twain_grammar.cfg')

twain_parser = nltk.ChartParser(twain_grammar)
for tree in twain_parser.parse(twain_quote):
    print(tree)
# Out:
# (S
#   (NP David)
#   (VP
#     (VP (Adv please) (V end))
#     (NP (Det this) (N (Adj eternal) (N nightmare)))))

# %% [markdown]
# **Generate 10 possible sentences from your new grammar.**

# %%
for sentence in generate(twain_grammar, n=10):
    print(' '.join(sentence))
# Out:
# this nightmare please end
# this nightmare please end this nightmare
# this nightmare please end this eternal nightmare
# this nightmare please end this eternal eternal nightmare
# this nightmare please end this eternal eternal eternal nightmare
# this nightmare please end this eternal eternal eternal eternal nightmare
# this nightmare please end this eternal eternal eternal eternal eternal nightmare
# this nightmare please end this eternal eternal eternal eternal eternal eternal nightmare
# this nightmare please end this eternal eternal eternal eternal eternal eternal eternal nightmare
# this nightmare please end this eternal eternal eternal eternal eternal eternal eternal eternal nightmare

# %% [markdown]
# ## Problem 4 (open-ended)

# %% [markdown]
# **Follow the example in section 6.1 to answer exercise 16.**

# %% [markdown]
# ### Exercise 16
#
# **Pick some common verbs and complete the following tasks**

# %%
my_verbs = ['declined', 'end', 'fell']

# %% [markdown]
# **a. Write a program to find those verbs in the Prepositional Phrase Attachment Corpus nltk.corpus.ppattach. Find any cases where the same verb exhibits two different attachments, but where the first noun, or second noun, or preposition, stay unchanged (as we saw in our discussion of syntactic ambiguity in 2).**

# %%
# What does the training set look like?
entries = nltk.corpus.ppattach.attachments('training')
for entry in entries:
    if entry.verb in my_verbs:
        print(entry)
# Out:
# PPAttachment(sent='389', verb='fell', noun1='%', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='1302', verb='end', noun1='December', prep='with', noun2='balance', attachment='V')
# PPAttachment(sent='1541', verb='fell', noun1='total', prep='of', noun2='points', attachment='N')
# PPAttachment(sent='1641', verb='fell', noun1='%', prep='in', noun2='1977', attachment='V')
# PPAttachment(sent='2808', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='2811', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='2813', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='2924', verb='fell', noun1='1.125', prep='to', noun2='13.625', attachment='V')
# PPAttachment(sent='2925', verb='fell', noun1='%', prep='to', noun2='%', attachment='V')
# PPAttachment(sent='2934', verb='fell', noun1='points', prep='to', noun2='35500.64', attachment='V')
# PPAttachment(sent='2952', verb='fell', noun1='yen', prep='to', noun2='692', attachment='V')
# PPAttachment(sent='3097', verb='fell', noun1='14', prep='to', noun2='111', attachment='V')
# PPAttachment(sent='3098', verb='fell', noun1='9', prep='to', noun2='103', attachment='V')
# PPAttachment(sent='3105', verb='fell', noun1='%', prep='in', noun2='quarter', attachment='V')
# PPAttachment(sent='3328', verb='declined', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='3364', verb='fell', noun1='7', prep='to', noun2='48', attachment='V')
# PPAttachment(sent='3776', verb='fell', noun1='3.20', prep='to', noun2='377.60', attachment='V')
# PPAttachment(sent='3777', verb='declined', noun1='cents', prep='to', noun2='5.2180', attachment='V')
# PPAttachment(sent='4244', verb='fell', noun1='%', prep='in', noun2='September', attachment='V')
# PPAttachment(sent='4257', verb='declined', noun1='5.16', prep='on', noun2='Monday', attachment='V')
# PPAttachment(sent='4273', verb='fell', noun1='yen', prep='to', noun2='yen', attachment='V')
# PPAttachment(sent='5995', verb='fell', noun1='cents', prep='in', noun2='October', attachment='V')
# PPAttachment(sent='6270', verb='fell', noun1='2.50', prep='to', noun2='50.875', attachment='V')
# PPAttachment(sent='6404', verb='declined', noun1='vote', prep='on', noun2='ban', attachment='N')
# PPAttachment(sent='6669', verb='fell', noun1='1', prep='to', noun2='50', attachment='V')
# PPAttachment(sent='6692', verb='fell', noun1='5', prep='to', noun2='27', attachment='V')
# PPAttachment(sent='6839', verb='fell', noun1='%', prep='in', noun2='September', attachment='V')
# PPAttachment(sent='7234', verb='fell', noun1='points', prep='to', noun2='35417.44', attachment='V')
# PPAttachment(sent='7295', verb='fell', noun1='%', prep='in', noun2='September', attachment='V')
# PPAttachment(sent='7371', verb='fell', noun1='%', prep='from', noun2='tons', attachment='V')
# PPAttachment(sent='7497', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='7655', verb='fell', noun1='3', prep='to', noun2='99', attachment='V')
# PPAttachment(sent='7666', verb='fell', noun1='%', prep='from', noun2='year', attachment='V')
# PPAttachment(sent='7676', verb='fell', noun1='1.14', prep='to', noun2='368.87', attachment='V')
# PPAttachment(sent='7885', verb='fell', noun1='point', prep='to', noun2='97.25', attachment='V')
# PPAttachment(sent='8513', verb='declined', noun1='%', prep='to', noun2='units', attachment='V')
# PPAttachment(sent='8515', verb='declined', noun1='month', prep='from', noun2='levels', attachment='V')
# PPAttachment(sent='8641', verb='fell', noun1='tons', prep='to', noun2='tons', attachment='V')
# PPAttachment(sent='9349', verb='fell', noun1='1.39', prep='to', noun2='451.37', attachment='V')
# PPAttachment(sent='9351', verb='fell', noun1='5.00', prep='to', noun2='432.61', attachment='V')
# PPAttachment(sent='9351', verb='fell', noun1='3.56', prep='to', noun2='528.56', attachment='V')
# PPAttachment(sent='9378', verb='fell', noun1='1', prep='to', noun2='13', attachment='V')
# PPAttachment(sent='9381', verb='fell', noun1='5', prep='to', noun2='13', attachment='V')
# PPAttachment(sent='10036', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='10645', verb='end', noun1='feud', prep='between', noun2='creditors', attachment='N')
# PPAttachment(sent='10689', verb='fell', noun1='cents', prep='on', noun2='Friday', attachment='V')
# PPAttachment(sent='10964', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='10972', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='11007', verb='end', noun1='state', prep='of', noun2='emergency', attachment='N')
# PPAttachment(sent='11277', verb='fell', noun1='cents', prep='to', noun2='16.25', attachment='V')
# PPAttachment(sent='11692', verb='fell', noun1='cents', prep='to', noun2='52.125', attachment='V')
# PPAttachment(sent='11693', verb='fell', noun1='2.50', prep='to', noun2='37.75', attachment='V')
# PPAttachment(sent='11740', verb='fell', noun1='%', prep='on', noun2='Friday', attachment='V')
# PPAttachment(sent='11750', verb='fell', noun1='7', prep='amid', noun2='concerns', attachment='V')
# PPAttachment(sent='11754', verb='fell', noun1='4', prep='to', noun2='15', attachment='V')
# PPAttachment(sent='11772', verb='fell', noun1='5', prep='to', noun2='286', attachment='V')
# PPAttachment(sent='11775', verb='fell', noun1='10', prep='to', noun2='250', attachment='V')
# PPAttachment(sent='11778', verb='fell', noun1='points', prep='to', noun2='35378.44', attachment='V')
# PPAttachment(sent='12370', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='12905', verb='declined', noun1='%', prep='in', noun2='period', attachment='V')
# PPAttachment(sent='13012', verb='fell', noun1='cents', prep='to', noun2='cents', attachment='V')
# PPAttachment(sent='13032', verb='end', noun1='cease-fire', prep='with', noun2='rebels', attachment='N')
# PPAttachment(sent='13036', verb='end', noun1='cease-fire', prep='in', noun2='response', attachment='V')
# PPAttachment(sent='13348', verb='fell', noun1='3', prep='to', noun2='point', attachment='N')
# PPAttachment(sent='13547', verb='fell', noun1='points', prep='to', noun2='2596.72', attachment='V')
# PPAttachment(sent='13556', verb='fell', noun1='5', prep='to', noun2='99', attachment='V')
# PPAttachment(sent='13565', verb='fell', noun1='3', prep='to', noun2='49', attachment='V')
# PPAttachment(sent='14078', verb='fell', noun1='%', prep='to', noun2='yen', attachment='V')
# PPAttachment(sent='14080', verb='fell', noun1='%', prep='to', noun2='yen', attachment='V')
# PPAttachment(sent='14949', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='16429', verb='fell', noun1='%', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='16574', verb='fell', noun1='5.80', prep='to', noun2='444.19', attachment='V')
# PPAttachment(sent='16590', verb='fell', noun1='1', prep='to', noun2='1', attachment='V')
# PPAttachment(sent='16599', verb='fell', noun1='5', prep='to', noun2='11', attachment='V')
# PPAttachment(sent='16634', verb='fell', noun1='39.55', prep='to', noun2='2613.73', attachment='V')
# PPAttachment(sent='16656', verb='fell', noun1='1', prep='to', noun2='100', attachment='V')
# PPAttachment(sent='16658', verb='fell', noun1='5', prep='to', noun2='55', attachment='V')
# PPAttachment(sent='16661', verb='fell', noun1='7', prep='to', noun2='41', attachment='V')
# PPAttachment(sent='16669', verb='fell', noun1='5', prep='to', noun2='43', attachment='V')
# PPAttachment(sent='16681', verb='fell', noun1='2.44', prep='to', noun2='373.48', attachment='V')
# PPAttachment(sent='16857', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='17331', verb='fell', noun1='0.10', prep='to', noun2='99.95', attachment='V')
# PPAttachment(sent='17786', verb='fell', noun1='million', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='18400', verb='fell', noun1='1.625', prep='to', noun2='108.625', attachment='V')
# PPAttachment(sent='18567', verb='fell', noun1='%', prep='in', noun2='August', attachment='V')
# PPAttachment(sent='19136', verb='fell', noun1='%', prep='in', noun2='quarter', attachment='V')
# PPAttachment(sent='19142', verb='fell', noun1='cents', prep='to', noun2='52.25', attachment='V')
# PPAttachment(sent='20802', verb='fell', noun1='1.50', prep='to', noun2='19.125', attachment='V')
# PPAttachment(sent='20820', verb='fell', noun1='points', prep='to', noun2='35442.40', attachment='V')
# PPAttachment(sent='20832', verb='fell', noun1='150', prep='to', noun2='4,290', attachment='V')
# PPAttachment(sent='20833', verb='fell', noun1='40', prep='to', noun2='1,520', attachment='V')
# PPAttachment(sent='20834', verb='fell', noun1='40', prep='to', noun2='2,680', attachment='V')
# PPAttachment(sent='20958', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='21040', verb='end', noun1='session', prep='at', noun2='19.62', attachment='V')
# PPAttachment(sent='21140', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='21168', verb='fell', noun1='5.94', prep='to', noun2='2653.28', attachment='V')
# PPAttachment(sent='21173', verb='fell', noun1='1.16', prep='to', noun2='320.94', attachment='V')
# PPAttachment(sent='21189', verb='fell', noun1='1', prep='to', noun2='59', attachment='V')
# PPAttachment(sent='21192', verb='fell', noun1='3', prep='to', noun2='12', attachment='V')
# PPAttachment(sent='21205', verb='fell', noun1='1', prep='to', noun2='37', attachment='V')
# PPAttachment(sent='21220', verb='fell', noun1='0.44', prep='to', noun2='375.92', attachment='V')
# PPAttachment(sent='21310', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='21445', verb='fell', noun1='%', prep='to', noun2='11,586', attachment='V')
# PPAttachment(sent='21634', verb='fell', noun1='3', prep='to', noun2='15', attachment='V')
# PPAttachment(sent='22010', verb='fell', noun1='cents', prep='in', noun2='trading', attachment='V')
# PPAttachment(sent='22037', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='22472', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='24563', verb='fell', noun1='%', prep='from', noun2='year', attachment='V')
# PPAttachment(sent='24564', verb='fell', noun1='%', prep='to', noun2='units', attachment='V')
# PPAttachment(sent='24616', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='24697', verb='fell', noun1='cents', prep='to', noun2='2.125', attachment='V')
# PPAttachment(sent='24824', verb='fell', noun1='1', prep='to', noun2='40', attachment='V')
# PPAttachment(sent='24825', verb='fell', noun1='3', prep='to', noun2='68', attachment='V')
# PPAttachment(sent='24828', verb='fell', noun1='4', prep='to', noun2='59', attachment='V')
# PPAttachment(sent='24832', verb='fell', noun1='1', prep='to', noun2='16', attachment='V')
# PPAttachment(sent='24839', verb='fell', noun1='7', prep='to', noun2='44', attachment='V')
# PPAttachment(sent='24851', verb='fell', noun1='3.10', prep='to', noun2='376.36', attachment='V')
# PPAttachment(sent='24864', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='24870', verb='fell', noun1='%', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='24889', verb='fell', noun1='points', prep='on', noun2='news', attachment='V')
# PPAttachment(sent='24898', verb='fell', noun1='1', prep='to', noun2='point', attachment='V')
# PPAttachment(sent='25206', verb='declined', noun1='%', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='25222', verb='declined', noun1='million', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='25228', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='25245', verb='end', noun1='involvement', prep='in', noun2='mining', attachment='N')
# PPAttachment(sent='25299', verb='fell', noun1='%', prep='from', noun2='tons', attachment='V')
# PPAttachment(sent='25574', verb='fell', noun1='points', prep='to', noun2='2662.91', attachment='V')
# PPAttachment(sent='26111', verb='fell', noun1='%', prep='to', noun2='cases', attachment='V')
# PPAttachment(sent='26202', verb='fell', noun1='1.75', prep='to', noun2='20.75', attachment='V')
# PPAttachment(sent='26240', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='26242', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='26245', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='26317', verb='fell', noun1='1', prep='to', noun2='33', attachment='V')
# PPAttachment(sent='26318', verb='fell', noun1='victim', prep='to', noun2='profit-taking', attachment='V')
# PPAttachment(sent='26318', verb='declined', noun1='1', prep='to', noun2='83', attachment='V')
# PPAttachment(sent='26341', verb='fell', noun1='1', prep='to', noun2='30', attachment='V')
# PPAttachment(sent='26449', verb='fell', noun1='%', prep='to', noun2='yen', attachment='V')
# PPAttachment(sent='26938', verb='fell', noun1='1.125', prep='to', noun2='23.125', attachment='V')
# PPAttachment(sent='26973', verb='fell', noun1='million', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='26973', verb='declined', noun1='million', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='27074', verb='fell', noun1='26.23', prep='to', noun2='2662.91', attachment='V')
# PPAttachment(sent='27092', verb='fell', noun1='1', prep='to', noun2='57', attachment='V')
# PPAttachment(sent='27099', verb='declined', noun1='1', prep='to', noun2='24', attachment='V')
# PPAttachment(sent='27104', verb='fell', noun1='5', prep='to', noun2='9', attachment='V')
# PPAttachment(sent='27108', verb='fell', noun1='1', prep='to', noun2='1', attachment='V')
# PPAttachment(sent='27112', verb='fell', noun1='1', prep='to', noun2='67', attachment='V')
# PPAttachment(sent='27121', verb='fell', noun1='3', prep='to', noun2='20', attachment='V')
# PPAttachment(sent='27296', verb='fell', noun1='cents', prep='to', noun2='19.76', attachment='V')
# PPAttachment(sent='27312', verb='fell', noun1='cents', prep='to', noun2='1.1960', attachment='V')
# PPAttachment(sent='27366', verb='fell', noun1='points', prep='to', noun2='2662.91', attachment='V')
# PPAttachment(sent='27437', verb='fell', noun1='point', prep='to', noun2='99.80', attachment='V')
# PPAttachment(sent='27437', verb='fell', noun1='0.10', prep='to', noun2='97.65', attachment='V')
# PPAttachment(sent='27890', verb='fell', noun1='cents', prep='to', noun2='50.50', attachment='V')
# PPAttachment(sent='27918', verb='declined', noun1='%', prep='from', noun2='year', attachment='V')
# PPAttachment(sent='27919', verb='fell', noun1='1.125', prep='in', noun2='trading', attachment='V')
# PPAttachment(sent='28095', verb='fell', noun1='%', prep='in', noun2='quarter', attachment='V')
# PPAttachment(sent='28413', verb='fell', noun1='1.375', prep='in', noun2='trading', attachment='V')
# PPAttachment(sent='28973', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='29186', verb='fell', noun1='%', prep='from', noun2='days', attachment='V')
# PPAttachment(sent='30311', verb='fell', noun1='average', prep='of', noun2='%', attachment='N')
# PPAttachment(sent='30317', verb='declined', noun1='%', prep='in', noun2='week', attachment='N')
# PPAttachment(sent='30537', verb='fell', noun1='week', prep='for', noun2='lack', attachment='V')
# PPAttachment(sent='30556', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='30639', verb='fell', noun1='1', prep='to', noun2='point', attachment='V')
# PPAttachment(sent='30692', verb='fell', noun1='%', prep='to', noun2='%', attachment='V')
# PPAttachment(sent='30995', verb='fell', noun1='0.02', prep='to', noun2='325.50', attachment='V')
# PPAttachment(sent='30995', verb='fell', noun1='0.05', prep='to', noun2='192.12', attachment='V')
# PPAttachment(sent='30999', verb='fell', noun1='32.71', prep='to', noun2='1230.80', attachment='V')
# PPAttachment(sent='31003', verb='fell', noun1='1', prep='to', noun2='31', attachment='V')
# PPAttachment(sent='31006', verb='fell', noun1='1', prep='to', noun2='52', attachment='V')
# PPAttachment(sent='31006', verb='declined', noun1='7', prep='to', noun2='45', attachment='V')
# PPAttachment(sent='31010', verb='fell', noun1='3', prep='to', noun2='1', attachment='V')
# PPAttachment(sent='31013', verb='fell', noun1='1', prep='to', noun2='9', attachment='V')
# PPAttachment(sent='31016', verb='fell', noun1='3', prep='to', noun2='29', attachment='V')
# PPAttachment(sent='33285', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='33786', verb='declined', noun1='rematch', prep='with', noun2='Kean', attachment='N')
# PPAttachment(sent='33822', verb='declined', noun1='%', prep='in', noun2='September', attachment='V')
# PPAttachment(sent='34939', verb='fell', noun1='%', prep='for', noun2='month', attachment='V')
# PPAttachment(sent='35502', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='35750', verb='fell', noun1='ounce', prep='to', noun2='370.60', attachment='V')
# PPAttachment(sent='35761', verb='fell', noun1='total', prep='of', noun2='cents', attachment='N')
# PPAttachment(sent='35761', verb='fell', noun1='total', prep='during', noun2='days', attachment='V')
# PPAttachment(sent='35767', verb='fell', noun1='barrel', prep='to', noun2='20.42', attachment='V')
# PPAttachment(sent='35942', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='36172', verb='end', noun1='war', prep='for', noun2='control', attachment='N')
# PPAttachment(sent='36207', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='36313', verb='declined', noun1='%', prep='to', noun2='billion', attachment='V')
# PPAttachment(sent='36315', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='36445', verb='fell', noun1='44', prep='to', noun2='861', attachment='V')
# PPAttachment(sent='36522', verb='end', noun1='some', prep='of', noun2='problems', attachment='N')
# PPAttachment(sent='36526', verb='fell', noun1='%', prep='for', noun2='month', attachment='V')
# PPAttachment(sent='36954', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='37017', verb='end', noun1='reliance', prep='on', noun2='others', attachment='N')
# PPAttachment(sent='37115', verb='declined', noun1='request', prep='for', noun2='a', attachment='N')
# PPAttachment(sent='37482', verb='fell', noun1='2', prep='to', noun2='184', attachment='V')
# PPAttachment(sent='37556', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='37583', verb='declined', noun1='%', prep='because', noun2='sale', attachment='V')
# PPAttachment(sent='37727', verb='fell', noun1='6.25', prep='to', noun2='191.75', attachment='V')
# PPAttachment(sent='38210', verb='fell', noun1='%', prep='in', noun2='1988', attachment='V')
# PPAttachment(sent='38385', verb='fell', noun1='%', prep='in', noun2='September', attachment='V')
# PPAttachment(sent='38516', verb='fell', noun1='%', prep='to', noun2='million', attachment='V')
# PPAttachment(sent='39083', verb='fell', noun1='cents', prep='to', noun2='81.50', attachment='V')
# PPAttachment(sent='39083', verb='fell', noun1='cents', prep='to', noun2='31.875', attachment='V')
# PPAttachment(sent='39086', verb='fell', noun1='cents', prep='to', noun2='19.625', attachment='V')
# PPAttachment(sent='39097', verb='declined', noun1='comment', prep='on', noun2='Petco', attachment='N')
# PPAttachment(sent='39678', verb='fell', noun1='11', prep='to', noun2='111', attachment='V')
# PPAttachment(sent='39686', verb='fell', noun1='point', prep='to', noun2='99.90', attachment='V')

# %% [markdown]
# Ok, so the entries is a list of PPAttachment objects, which have sentence_id, verb, noun1, preposition, noun2, and attachment member variables. This really looks like it should be a data frame. Let's convert it. If you don't have pandas installed on your user, you should go install it (perhaps for everyone with sudo).

# %%
import pandas as pd

sent_ids = []
verbs = []
noun1s = []
preps = []
noun2s = []
attachments = []
for entry in entries:
    if entry.verb in my_verbs:
        sent_ids.append(entry.sent)
        verbs.append(entry.verb)
        noun1s.append(entry.noun1)
        preps.append(entry.prep)
        noun2s.append(entry.noun2)
        attachments.append(entry.attachment)
        
df = pd.DataFrame(dict(sent_id=sent_ids, verb=verbs, noun1=noun1s,
                       prep=preps, noun2=noun2s, attachment=attachments))
print(df.head())
# Out:
#   attachment     noun1    noun2  prep sent_id  verb
# 0          V         %  billion    to     389  fell
# 1          V  December  balance  with    1302   end
# 2          N     total   points    of    1541  fell
# 3          V         %     1977    in    1641  fell
# 4          V         %  million    to    2808  fell

# %%
for label in ['noun1', 'prep', 'noun2']:
    print("Example entries with same verb and %s but different attachments:" % label)
    ambiguous_entries = df[df.groupby(['verb', label])['attachment'].transform('nunique') > 1].sort_values(['verb', label])
    print(ambiguous_entries[['verb', 'noun1', 'prep', 'noun2', 'attachment']])
    print('')
# Out:
# Example entries with same verb and noun1 but different attachments:
#          verb       noun1     prep      noun2 attachment
# 14   declined           %       to    million          V
# 35   declined           %       to      units          V
# 59   declined           %       in     period          V
# 121  declined           %       to    billion          V
# 153  declined           %     from       year          V
# 160  declined           %       in       week          N
# 176  declined           %       in  September          V
# 186  declined           %       to    billion          V
# 196  declined           %  because       sale          V
# 61        end  cease-fire     with     rebels          N
# 62        end  cease-fire       in   response          V
# 31       fell           3       to         99          V
# 63       fell           3       to      point          N
# 66       fell           3       to         49          V
# 98       fell           3       to         12          V
# 103      fell           3       to         15          V
# 112      fell           3       to         68          V
# 146      fell           3       to         20          V
# 171      fell           3       to          1          V
# 173      fell           3       to         29          V
# 2        fell       total       of     points          N
# 180      fell       total       of      cents          N
# 181      fell       total   during       days          V
#
# Example entries with same verb and prep but different attachments:
#          verb        noun1  prep      noun2 attachment
# 59   declined            %    in     period          V
# 160  declined            %    in       week          N
# 176  declined            %    in  September          V
# 19   declined         5.16    on     Monday          V
# 23   declined         vote    on        ban          N
# 204  declined      comment    on      Petco          N
# 62        end   cease-fire    in   response          V
# 124       end  involvement    in     mining          N
# 1         end     December  with    balance          V
# 61        end   cease-fire  with     rebels          N
# 0        fell            %    to    billion          V
# 4        fell            %    to    million          V
# 5        fell            %    to    million          V
# 6        fell            %    to    million          V
# 7        fell        1.125    to     13.625          V
# 8        fell            %    to          %          V
# 9        fell       points    to   35500.64          V
# 10       fell          yen    to        692          V
# 11       fell           14    to        111          V
# 12       fell            9    to        103          V
# 15       fell            7    to         48          V
# 16       fell         3.20    to     377.60          V
# 20       fell          yen    to        yen          V
# 22       fell         2.50    to     50.875          V
# 24       fell            1    to         50          V
# 25       fell            5    to         27          V
# 27       fell       points    to   35417.44          V
# 30       fell            %    to    million          V
# 31       fell            3    to         99          V
# 33       fell         1.14    to     368.87          V
# ..        ...          ...   ...        ...        ...
# 157      fell            %    to    million          V
# 162      fell            %    to    million          V
# 163      fell            1    to      point          V
# 164      fell            %    to          %          V
# 165      fell         0.02    to     325.50          V
# 166      fell         0.05    to     192.12          V
# 167      fell        32.71    to    1230.80          V
# 168      fell            1    to         31          V
# 169      fell            1    to         52          V
# 171      fell            3    to          1          V
# 172      fell            1    to          9          V
# 173      fell            3    to         29          V
# 174      fell            %    to    million          V
# 178      fell            %    to    million          V
# 179      fell        ounce    to     370.60          V
# 182      fell       barrel    to      20.42          V
# 183      fell            %    to    million          V
# 185      fell            %    to    million          V
# 187      fell            %    to    million          V
# 188      fell           44    to        861          V
# 191      fell            %    to    million          V
# 194      fell            2    to        184          V
# 195      fell            %    to    million          V
# 197      fell         6.25    to     191.75          V
# 200      fell            %    to    million          V
# 201      fell        cents    to      81.50          V
# 202      fell        cents    to     31.875          V
# 203      fell        cents    to     19.625          V
# 205      fell           11    to        111          V
# 206      fell        point    to      99.90          V
#
# [156 rows x 5 columns]
#
# Example entries with same verb and noun2 but different attachments:
#      verb    noun1 prep  noun2 attachment
# 8    fell        %   to      %          V
# 159  fell  average   of      %          N
# 164  fell        %   to      %          V
# 60   fell    cents   to  cents          V
# 180  fell    total   of  cents          N
# 63   fell        3   to  point          N
# 120  fell        1   to  point          V
# 163  fell        1   to  point          V

# %% [markdown]
# **b. Devise CFG grammar productions to cover some of these cases.**

# %% [markdown]
# ???

# %% [markdown]
# ## Problem 5
#
# **Use the method of Church to find the most likely parsing of the sentence, "I tried to please you." Show each step, especially the last step ("I") where the use of the trigram model for context probability allows the algorithm to prune the search to run in linear time in the length of the sentence.**

# %% [markdown]
# First I'll get the tagged counts for each word that shows up in our sentence, within the Tagged Brown Corpus.

# %%
from nltk.corpus import brown

sent = "I tried to please you".split()

# Keys are (word, part-of-speech), values
# are frequency counts of that pair
word_tag_counts = {}
for word, pos in brown.tagged_words():
    
    if word in sent:
        word_tag_counts[(word, pos)] = word_tag_counts.get((word, pos), 0) + 1

print(word_tag_counts)
# Out:
# {('I', 'NP'): 1, ('I', 'PPSS-HL'): 2, ('you', 'PPSS'): 1864, ('I', 'NIL'): 1, ('please', 'VB'): 37, ('tried', 'VBN'): 50, ('you', 'PPSS-HL'): 1, ('to', 'NPS'): 1, ('to', 'TO-HL'): 50, ('to', 'TO-NC'): 13, ('to', 'IN-TL'): 12, ('I', 'NN-TL'): 1, ('you', 'PPO'): 889, ('please', 'UH'): 8, ('to', 'QL'): 1, ('to', 'NIL'): 3, ('to', 'IN-NC'): 8, ('tried', 'VBD'): 120, ('you', 'PPO-HL'): 1, ('I', 'PPSS'): 5129, ('you', 'PPO-NC'): 4, ('to', 'TO'): 14679, ('you', 'PPSS-NC'): 7, ('to', 'IN'): 10903, ('I', 'NN'): 3, ('to', 'IN-HL'): 62, ('I', 'PPSS-NC'): 24}

# %% [markdown]
# Ok, so we counted (word, part-of-speech) pairs. Now each of those entries can be cataloged in a data frame.

# %%
# Create part-of-speech frequencies data frame in long-form
pos_frequencies = pd.DataFrame(columns=['word', 'pos', 'count'])
for i, key in enumerate(word_tag_counts.keys()):
    word = key[0]
    pos = key[1]
    pos_frequencies.loc[i] = [word, pos, word_tag_counts[(word, pos)]]  # add row to data frame
    
print(pos_frequencies.head())
# Out:
#      word      pos count
# 0       I       NP     1
# 1       I  PPSS-HL     2
# 2     you     PPSS  1864
# 3       I      NIL     1
# 4  please       VB    37

# %% [markdown]
# We're going to need lexical probabilities, so let's compute those now. For each (word, part-of-speech) pair, we'll divide the count by the count of that word (which is the sum of counts over all parts of speech for that word). Also, since these probabilities can get small, we'll take the log of the probabilities.

# %%
import numpy as np

# Calculate lexical probabilities by taking count(word,pos) / count(word)
pos_frequencies['lexical_probs'] = pos_frequencies.groupby('word')['count'].transform(lambda x: x / x.sum())

# Get log probs
pos_frequencies['lexical_log_probs'] = np.log(pos_frequencies['lexical_probs'].astype(np.float64))

print(pos_frequencies.head())
# Out:
#      word      pos count lexical_probs  lexical_log_probs
# 0       I       NP     1   0.000193761          -8.548886
# 1       I  PPSS-HL     2   0.000387522          -7.855738
# 2     you     PPSS  1864      0.673897          -0.394678
# 3       I      NIL     1   0.000193761          -8.548886
# 4  please       VB    37      0.822222          -0.195745

# %% [markdown]
# Awesome. We are going to need unigram, bigram and trigram counts for parts of speech, in order to compute the contextual probabilities. I can't easily find a simple nltk way to do this, so we'll have to manually build these. First build the unigram table.

# %%
# parts of speech that we're interested in (that could occur in our sentence)
all_pos = set(pos_frequencies['pos'].unique())

# (pos) -> unigram_count
unigram_pos_counts = {pos: 1 for pos in all_pos}  # laplace smoothed

# handle start tag
unigram_pos_counts[''] = 1
    
for word, pos in brown.tagged_words():

    # Only count if this part of speech is one we're interested in
    if pos in all_pos:
        unigram_pos_counts[pos] += 1
        
    # Naive approach - using periods as start tags
    if pos == '.':
        unigram_pos_counts[''] += 1

print(unigram_pos_counts)
# Out:
# {'': 60639, 'PPO': 11182, 'PPSS': 13803, 'NPS': 1276, 'PPO-HL': 6, 'NP': 34477, 'IN': 120558, 'IN-NC': 42, 'IN-TL': 1478, 'TO': 14919, 'NN-TL': 13373, 'VBD': 26168, 'VBN': 29187, 'IN-HL': 509, 'UH': 609, 'NIL': 158, 'PPSS-HL': 26, 'PPSS-NC': 32, 'NN': 152471, 'PPO-NC': 10, 'VB': 33694, 'QL': 8736, 'TO-NC': 14, 'TO-HL': 56}

# %% [markdown]
# Then the bigram table.

# %%
# (pos1, pos2) -> bigram_count
bigram_pos_counts = {(pos1, pos2): 1 for pos1 in all_pos for pos2 in all_pos}  # laplace smoothed

# handle start tags
start_bigrams = [('', pos) for pos in all_pos]
for start_bigram in start_bigrams:
    bigram_pos_counts[start_bigram] = 1
    
for t1, t2 in zip(brown.tagged_words()[:-1], brown.tagged_words()[1:]):
    pos1 = t1[1]
    pos2 = t2[1]
    
    # Only count bigram if both parts of speech are ones we're interested in
    if pos1 in all_pos and pos2 in all_pos:
        bigram_pos_counts[(pos1, pos2)] += 1
    # Naive approach - using periods as start tags
    elif pos1 == '.' and pos2 in all_pos:
        bigram_pos_counts[('', pos2)] += 1

print(bigram_pos_counts)
# Out:
# {('PPO', 'VB'): 438, ('PPO-HL', 'PPO'): 1, ('IN-HL', 'NP'): 1, ('PPSS-HL', 'VBD'): 1, ('PPO-NC', 'PPO-HL'): 1, ('PPO', 'TO-NC'): 1, ('NPS', 'VBN'): 7, ('TO', 'NN-TL'): 1, ('IN-TL', 'PPSS-NC'): 1, ('NIL', 'IN-NC'): 1, ('UH', 'NIL'): 1, ('PPSS-HL', 'NN'): 1, ('IN-NC', 'IN-TL'): 1, ('NP', 'TO-NC'): 1, ('NN-TL', 'NN'): 522, ('', 'NN'): 1246, ('NN-TL', 'IN-HL'): 3, ('NN-TL', 'IN'): 852, ('NN-TL', 'PPSS'): 17, ('PPSS-HL', 'UH'): 1, ('TO', 'NIL'): 1, ('TO-HL', 'NIL'): 1, ('IN-NC', 'PPSS-HL'): 1, ('IN', 'VBN'): 616, ('NIL', 'NPS'): 1, ('VBD', 'TO'): 1220, ('IN-NC', 'VBD'): 1, ('PPO-NC', 'PPSS'): 1, ('PPSS', 'PPSS-NC'): 1, ('TO-HL', 'NN-TL'): 1, ('IN-HL', 'PPO-NC'): 1, ('TO-NC', 'TO'): 1, ('PPSS-NC', 'NN-TL'): 1, ('IN-HL', 'IN'): 1, ('IN-NC', 'TO'): 1, ('VBN', 'VBD'): 15, ('TO-HL', 'PPO'): 1, ('NPS', 'PPO'): 1, ('TO-NC', 'VBN'): 1, ('UH', 'NN-TL'): 2, ('VB', 'PPSS-HL'): 1, ('PPSS-HL', 'PPSS-HL'): 1, ('PPO', 'PPSS-HL'): 1, ('TO-NC', 'PPO-NC'): 1, ('NP', 'VBD'): 3828, ('NN', 'NPS'): 15, ('PPSS-HL', 'NN-TL'): 1, ('QL', 'IN-NC'): 1, ('PPSS', 'NN'): 17, ('IN-HL', 'IN-HL'): 5, ('PPSS', 'IN'): 27, ('VBN', 'PPO'): 579, ('VBN', 'VB'): 23, ('', 'VB'): 729, ('NN', 'TO-HL'): 1, ('TO-HL', 'NPS'): 1, ('NN', 'UH'): 2, ('PPO', 'TO'): 520, ('IN-HL', 'PPO'): 1, ('NN-TL', 'VBN'): 23, ('VBD', 'QL'): 239, ('NIL', 'NIL'): 127, ('TO', 'NN'): 7, ('NP', 'IN'): 1647, ('IN', 'PPO'): 4007, ('TO', 'IN'): 5, ('NIL', 'PPSS-HL'): 1, ('PPSS', 'QL'): 25, ('VBD', 'IN-HL'): 1, ('TO', 'VB'): 12292, ('NPS', 'QL'): 8, ('PPO', 'PPO-NC'): 1, ('IN-NC', 'IN-NC'): 1, ('VBN', 'QL'): 236, ('VB', 'NPS'): 9, ('NN', 'NP'): 644, ('IN', 'NN'): 17226, ('NIL', 'TO-HL'): 1, ('PPSS-NC', 'IN'): 1, ('PPO-NC', 'VBN'): 1, ('PPSS-NC', 'PPO-NC'): 1, ('IN-HL', 'QL'): 1, ('TO', 'QL'): 2, ('UH', 'TO-HL'): 1, ('PPO-HL', 'PPO-HL'): 1, ('PPSS-HL', 'IN-TL'): 1, ('IN-NC', 'IN-HL'): 1, ('PPO', 'PPO-HL'): 1, ('VBN', 'PPSS-HL'): 1, ('PPSS-NC', 'UH'): 1, ('IN', 'TO'): 23, ('VBD', 'PPO'): 1995, ('VB', 'IN-NC'): 1, ('VB', 'NN'): 1464, ('PPSS-NC', 'QL'): 1, ('IN-TL', 'IN-NC'): 1, ('NP', 'TO'): 225, ('QL', 'NP'): 4, ('PPO-NC', 'IN-HL'): 1, ('PPSS-HL', 'PPSS'): 1, ('QL', 'IN-TL'): 1, ('PPO-NC', 'PPSS-NC'): 1, ('PPSS-HL', 'VB'): 1, ('NPS', 'TO'): 20, ('TO', 'PPO'): 4, ('IN-NC', 'VBN'): 1, ('IN-NC', 'PPO-NC'): 2, ('IN-HL', 'NPS'): 1, ('NIL', 'NN-TL'): 1, ('NP', 'PPO-NC'): 1, ('VBN', 'NN-TL'): 54, ('NN-TL', 'IN-TL'): 1190, ('NP', 'NP'): 7648, ('IN-NC', 'NPS'): 1, ('PPSS-NC', 'TO-NC'): 1, ('IN', 'TO-NC'): 2, ('NN-TL', 'VB'): 41, ('NPS', 'PPO-HL'): 1, ('TO', 'VBD'): 1, ('', 'PPO-NC'): 1, ('QL', 'NN'): 17, ('', 'PPO-HL'): 1, ('NP', 'UH'): 3, ('IN-TL', 'TO-NC'): 1, ('NN-TL', 'PPO-NC'): 1, ('TO', 'TO-NC'): 1, ('VBD', 'VBD'): 11, ('PPO-NC', 'TO-HL'): 1, ('VBD', 'NN-TL'): 57, ('PPSS', 'IN-TL'): 1, ('VBN', 'NIL'): 1, ('PPO-HL', 'QL'): 1, ('NPS', 'IN'): 131, ('UH', 'PPO'): 1, ('IN-HL', 'PPO-HL'): 2, ('PPSS-HL', 'NP'): 1, ('PPO-NC', 'NP'): 1, ('VBD', 'NPS'): 7, ('NIL', 'PPSS-NC'): 1, ('IN-HL', 'NIL'): 1, ('PPSS-HL', 'NIL'): 1, ('', 'IN-TL'): 2, ('PPO', 'NP'): 28, ('PPO-NC', 'IN-NC'): 1, ('PPSS-NC', 'NIL'): 1, ('UH', 'PPO-NC'): 1, ('VB', 'PPO-HL'): 1, ('IN-TL', 'IN-HL'): 1, ('PPSS-NC', 'PPO-HL'): 1, ('TO', 'PPSS'): 1, ('NIL', 'VB'): 1, ('IN', 'VBD'): 4, ('NP', 'NPS'): 59, ('PPO-HL', 'NPS'): 1, ('TO', 'PPSS-HL'): 1, ('', 'UH'): 143, ('UH', 'TO'): 1, ('VB', 'TO-HL'): 1, ('VB', 'IN-HL'): 1, ('', 'NIL'): 3, ('NIL', 'NN'): 1, ('PPSS-NC', 'IN-TL'): 1, ('PPSS-NC', 'PPSS'): 1, ('VBD', 'NIL'): 1, ('NPS', 'PPSS-HL'): 1, ('TO-NC', 'NP'): 1, ('NN', 'VB'): 605, ('PPSS', 'PPSS-HL'): 1, ('NIL', 'QL'): 1, ('', 'NPS'): 20, ('NIL', 'IN'): 3, ('TO-NC', 'VBD'): 1, ('PPO', 'UH'): 4, ('PPO', 'NN'): 132, ('TO-HL', 'TO-HL'): 1, ('IN', 'TO-HL'): 1, ('NN-TL', 'NN-TL'): 1915, ('TO-HL', 'IN'): 1, ('IN-TL', 'NN-TL'): 412, ('IN-HL', 'NN'): 1, ('IN-NC', 'PPSS'): 1, ('TO-NC', 'IN-NC'): 1, ('NP', 'VBN'): 61, ('PPO-HL', 'NIL'): 1, ('NN-TL', 'NIL'): 1, ('IN-NC', 'TO-HL'): 1, ('PPSS-HL', 'TO'): 1, ('PPO', 'QL'): 141, ('IN-TL', 'PPO-NC'): 1, ('VBN', 'PPO-NC'): 1 ...

# %% [markdown]
# And now the trigram table.

# %%
# (pos1, pos2, pos3) -> trigram_count
trigram_pos_counts = {(pos1, pos2, pos3): 1 for pos1 in all_pos for pos2 in all_pos for pos3 in all_pos}  # laplace smoothed

# handle start tags
single_start_trigrams = [('', pos1, pos2) for pos1 in all_pos for pos2 in all_pos]
for start_trigram in single_start_trigrams:
    trigram_pos_counts[start_trigram] = 1
    
double_start_trigrams = [('', '', pos) for pos in all_pos]
for start_trigram in double_start_trigrams:
    trigram_pos_counts[start_trigram] = 1
    
for t1, t2, t3 in zip(brown.tagged_words()[:-2], brown.tagged_words()[1:-1], brown.tagged_words()[2:]):
    pos1 = t1[1]
    pos2 = t2[1]
    pos3 = t3[1]
    
    # Only count trigram if all three parts of speech are ones we're interested in
    if pos1 in all_pos and pos2 in all_pos and pos3 in all_pos:
        trigram_pos_counts[(pos1, pos2, pos3)] += 1  
    # Naive approach - using periods as start tags
    elif pos1 == '.' and pos2 in all_pos and pos3 in all_pos:
        trigram_pos_counts[('', pos2, pos3)] += 1
    elif pos2 == '.' and pos3 in all_pos:
        trigram_pos_counts[('', '', pos3)] += 1

print(trigram_pos_counts)
# Out:
# {('NN-TL', 'PPO-HL', 'IN-NC'): 1, ('IN', 'PPSS-HL', 'IN-TL'): 1, ('PPO-HL', 'PPSS', 'PPSS'): 1, ('IN-TL', 'VBN', 'PPO-HL'): 1, ('VB', 'IN', 'IN-NC'): 1, ('PPSS-HL', 'NP', 'IN'): 1, ('PPSS', 'VBD', 'QL'): 28, ('NP', 'IN', 'TO'): 1, ('PPO-NC', 'IN-HL', 'NN-TL'): 1, ('PPSS-NC', 'PPSS', 'IN-TL'): 1, ('VBD', 'PPO', 'PPSS'): 13, ('QL', 'TO-NC', 'PPO-HL'): 1, ('NP', 'PPSS-NC', 'PPO'): 1, ('VBN', 'QL', 'TO-NC'): 1, ('NN-TL', 'PPSS-NC', 'VBN'): 1, ('UH', 'IN', 'PPSS'): 1, ('NP', 'PPSS', 'IN'): 1, ('VB', 'TO-HL', 'IN-TL'): 1, ('PPO-NC', 'VBD', 'VBD'): 1, ('NPS', 'NIL', 'VB'): 1, ('QL', 'TO', 'NPS'): 1, ('TO-HL', 'QL', 'IN-NC'): 1, ('VBD', 'VBD', 'PPO'): 1, ('PPSS-NC', 'PPSS', 'UH'): 1, ('VB', 'VBD', 'IN'): 2, ('TO-NC', 'TO-NC', 'NN-TL'): 1, ('PPO-NC', 'TO', 'NN-TL'): 1, ('NN', 'TO-NC', 'PPO-NC'): 1, ('NP', 'NPS', 'PPO-NC'): 1, ('TO-HL', 'NPS', 'PPO'): 1, ('VBD', 'TO', 'NIL'): 1, ('IN-HL', 'PPO-HL', 'UH'): 1, ('IN', 'NPS', 'VB'): 2, ('VB', 'PPSS-NC', 'PPSS-NC'): 1, ('IN-HL', 'PPO-HL', 'PPO-NC'): 1, ('NN-TL', 'IN-NC', 'IN-NC'): 1, ('PPSS-NC', 'PPSS', 'PPO-NC'): 1, ('NN-TL', 'IN-NC', 'TO'): 1, ('PPSS', 'NN-TL', 'IN-TL'): 1, ('PPSS', 'IN-TL', 'NIL'): 1, ('VB', 'NIL', 'PPO-NC'): 1, ('VBD', 'NN', 'TO-HL'): 1, ('PPO', 'UH', 'PPO-NC'): 1, ('PPSS', 'NN-TL', 'TO-HL'): 1, ('IN-HL', 'NPS', 'PPSS'): 1, ('NN', 'NP', 'IN-TL'): 3, ('PPSS-NC', 'IN-NC', 'NPS'): 1, ('VBN', 'TO-HL', 'TO'): 1, ('PPO-HL', 'PPO-NC', 'PPSS'): 1, ('IN-HL', 'NIL', 'PPSS-NC'): 1, ('VBD', 'NN', 'TO'): 15, ('NP', 'PPO-NC', 'PPO-NC'): 1, ('PPO', 'UH', 'TO-NC'): 1, ('IN-TL', 'IN-HL', 'VBD'): 1, ('', 'VB', 'PPO'): 114, ('PPSS', 'TO', 'PPO'): 1, ('PPO-HL', 'NPS', 'UH'): 1, ('TO', 'NP', 'TO'): 1, ('QL', 'NIL', 'TO-NC'): 1, ('TO', 'VBN', 'IN-HL'): 1, ('PPSS-NC', 'IN', 'NN'): 1, ('PPSS-HL', 'QL', 'NN'): 1, ('NN-TL', 'IN-HL', 'PPSS-NC'): 1, ('NN', 'QL', 'NN-TL'): 1, ('IN-HL', 'TO', 'TO'): 1, ('VBD', 'UH', 'PPSS-HL'): 1, ('', 'VBD', 'IN-TL'): 1, ('NIL', 'IN', 'NPS'): 1, ('IN', 'PPO-HL', 'TO-NC'): 1, ('', 'PPSS-NC', 'PPSS-NC'): 1, ('PPO-HL', 'IN', 'PPSS-NC'): 1, ('PPO', 'PPO-NC', 'TO'): 1, ('QL', 'IN-NC', 'NIL'): 1, ('IN-HL', 'PPSS-HL', 'PPSS-NC'): 1, ('PPSS-NC', 'NIL', 'IN-NC'): 1, ('NN', 'NIL', 'TO'): 1, ('NIL', 'NN', 'IN'): 1, ('NN', 'QL', 'PPSS'): 1, ('PPO', 'TO-NC', 'PPO-NC'): 1, ('IN-NC', 'PPO-NC', 'PPSS-HL'): 1, ('NN-TL', 'VB', 'TO-NC'): 1, ('TO', 'NPS', 'IN-HL'): 1, ('IN-HL', 'IN-HL', 'PPO-NC'): 1, ('NIL', 'PPSS-HL', 'TO'): 1, ('PPO', 'VB', 'PPO-HL'): 1, ('PPO-HL', 'VBN', 'IN-HL'): 1, ('PPO', 'PPSS-NC', 'NIL'): 1, ('PPO-NC', 'NN-TL', 'TO'): 1, ('NIL', 'NPS', 'NIL'): 1, ('PPO-HL', 'IN-NC', 'PPO'): 1, ('', 'PPSS-HL', 'VB'): 1, ('IN-TL', 'NIL', 'PPSS'): 1, ('PPSS', 'NPS', 'TO'): 1, ('PPSS-HL', 'NPS', 'UH'): 1, ('TO-NC', 'IN-HL', 'NN-TL'): 1, ('TO', 'VBN', 'PPO-NC'): 1, ('PPO-NC', 'VBN', 'IN-NC'): 1, ('TO', 'TO-HL', 'PPSS-NC'): 1, ('PPO-HL', 'IN-TL', 'NIL'): 1, ('PPO-HL', 'IN-NC', 'NPS'): 1, ('NN', 'TO-HL', 'TO-NC'): 1, ('NPS', 'VBN', 'VB'): 1, ('NN-TL', 'NIL', 'TO'): 1, ('QL', 'NP', 'NP'): 1, ('NN-TL', 'IN-NC', 'PPSS-NC'): 1, ('IN-HL', 'NN', 'UH'): 1, ('UH', 'NIL', 'VBN'): 1, ('TO-NC', 'PPO', 'TO'): 1, ('NN', 'PPSS-NC', 'IN'): 1, ('PPSS-HL', 'NPS', 'NN-TL'): 1, ('VBD', 'QL', 'IN-TL'): 1, ('TO-NC', 'IN-NC', 'VBN'): 1, ('IN', 'PPO', 'UH'): 1, ('TO-NC', 'UH', 'VBN'): 1, ('NIL', 'IN', 'TO-NC'): 1, ('IN-HL', 'NP', 'PPO-NC'): 1, ('UH', 'NN', 'TO-HL'): 1, ('NP', 'IN', 'IN'): 12, ('', 'NP', 'TO-NC'): 1, ('NPS', 'VBD', 'NP'): 4, ('IN', 'QL', 'NIL'): 1, ('IN-NC', 'PPO', 'TO-NC'): 1, ('NPS', 'NN-TL', 'NP'): 1, ('PPO-HL', 'PPO', 'VBN'): 1, ('PPO-NC', 'NN-TL', 'IN-TL'): 1, ('NIL', 'PPSS-HL', 'IN-TL'): 1, ('VB', 'PPO', 'PPSS'): 17, ('PPSS-NC', 'NN-TL', 'PPO'): 1, ('UH', 'NN', 'PPO'): 1, ('PPO-HL', 'PPSS-HL', 'NPS'): 1, ('NP', 'IN-NC', 'VBN'): 1, ('IN', 'IN-HL', 'UH'): 1, ('PPSS-HL', 'QL', 'NIL'): 1, ('NN-TL', 'NN-TL', 'VB'): 7, ('PPO-HL', 'PPSS', 'PPO-HL'): 1, ('UH', 'TO-NC', 'PPSS-NC'): 1, ('QL', 'NN-TL', 'TO-HL'): 1, ('QL', 'PPSS', 'IN'): 1, ('VB', 'NN-TL', 'PPO-NC'): 1, ('VB', 'IN', 'PPSS-NC'): 1, ...

# %% [markdown]
# Ok. Now we will be able to build the contextual probabilities when we need them. The contextual probability is the probability of observing part of speech X given the following two parts of speech Y and Z. We will estimate this by dividing the count of trigram XYZ by the count of bigram YZ. Similarly for the case when X is followed only by Y, we will estimate the contextual probability by dividing the count of bigram XY by the count of unigram Y.
#
# Now we have all the pieces necessary for generating scores for partial tagged sequences.

# %%
def compute_contextual_log_probability(pos_sequence):
    """ Take in an iterable listing a sequence of parts of speech. """
    
    pos_window = pos_sequence[:3]
    
    num_pos_in_window = len(pos_window)
    
    if num_pos_in_window == 1:  # contextual prob of a single pos gives no info, so prob = 1, logprob = 0
        return 0
    elif num_pos_in_window == 2:
        X = pos_sequence[0]
        Y = pos_sequence[1]
        
        bigram_count = bigram_pos_counts[(X, Y)]
        unigram_count = unigram_pos_counts[Y]
        
        return np.log(bigram_count / unigram_count)
    else:  # trigram
        X = pos_sequence[0]
        Y = pos_sequence[1]
        Z = pos_sequence[2]
        
        trigram_count = trigram_pos_counts[(X, Y, Z)]
        bigram_count = bigram_pos_counts[(Y, Z)]
        
        return np.log(trigram_count / bigram_count)

test_sequences = [['NP'],
                  ['NP', 'VB'],
                  ['NP', 'VB', 'PPO']]

for test_sequence in test_sequences:
    print(test_sequence, ": ", compute_contextual_log_probability(test_sequence))
# Out:
# ['NP'] :  0
# ['NP', 'VB'] :  -5.221068371869354
# ['NP', 'VB', 'PPO'] :  -4.855928904335275

# %% [markdown]
# We made this convenient function that we can vectorize.

# %% [markdown]
# Now we can start tagging our sentence. Starting with the last word, 'you', let's get our partial sequence scores.

# %%
# Get all assignments of parts of speech to 'you', and their lexical log probabilities
you_assignments = pos_frequencies[pos_frequencies.word == 'you'][['lexical_log_probs', 'pos']]

# This data frame will hold all the current candidate best assignments for partial sequences
partial_sequences = pd.DataFrame(you_assignments['pos'])

# Glue code
partial_sequences['pos_list'] = partial_sequences['pos'].apply(lambda s: (s,))  # make tuple of length 1

# Multiply together lexical probability with contextual probability to get score of sequence
# Adding in log space is multiplying in probability space
partial_sequences['score'] = you_assignments['lexical_log_probs'] + \
                             partial_sequences['pos_list'].apply(compute_contextual_log_probability)

partial_sequences = partial_sequences[['score', 'pos_list']].reset_index(drop=True)
print(partial_sequences)
# Out:
#       score    pos_list
# 0 -0.394678     (PPSS,)
# 1 -7.925158  (PPSS-HL,)
# 2 -1.135060      (PPO,)
# 3 -7.925158   (PPO-HL,)
# 4 -6.538863   (PPO-NC,)
# 5 -5.979247  (PPSS-NC,)

# %% [markdown]
# The next word of our sentence is 'please'.

# %%
# Get all assignments of parts of speech to 'please', and their lexical log probabilities
please_assignments = pos_frequencies[pos_frequencies.word == 'please'][['lexical_log_probs', 'pos']]

# Compute the cross product (all combinations) of the two series of parts of speech,
# to generate all part of speech assignments for the two-word sequence 'please you'
cross_product = partial_sequences.assign(tmp=1).merge(please_assignments.assign(tmp=1),
                                                      how='outer', on='tmp').drop('tmp', axis=1)

# Combine the parts of speech with the splat operator
cross_product['pos_list'] = cross_product.apply(lambda row: (row['pos'], *row['pos_list']), axis=1)

# Add new probability to old
cross_product['score'] += cross_product['lexical_log_probs'] + \
                          cross_product['pos_list'].apply(compute_contextual_log_probability)

# Throw away the log prob columns we no longer need
partial_sequences = cross_product[['score', 'pos_list']].reset_index(drop=True)
print(partial_sequences)
# Out:
#         score       pos_list
# 0   -4.663478     (VB, PPSS)
# 1   -9.708630     (UH, PPSS)
# 2  -11.378999  (VB, PPSS-HL)
# 3  -12.910475  (UH, PPSS-HL)
# 4   -2.618883      (VB, PPO)
# 5  -12.184342      (UH, PPO)
# 6   -9.912662   (VB, PPO-HL)
# 7  -11.444138   (UH, PPO-HL)
# 8   -9.037193   (VB, PPO-NC)
# 9  -10.568669   (UH, PPO-NC)
# 10  -8.947581  (VB, PPSS-NC)
# 11 -11.172204  (UH, PPSS-NC)

# %% [markdown]
# The next word of our sentence is 'to'.

# %%
# Get all assignments of parts of speech to 'to', and their lexical log probabilities
to_assignments = pos_frequencies[pos_frequencies.word == 'to'][['lexical_log_probs', 'pos']]

# Compute the cross product (all combinations) of the two series of parts of speech,
# to generate all part of speech assignments for the three-word sequence 'to please you'
cross_product = partial_sequences.assign(tmp=1).merge(to_assignments.assign(tmp=1),
                                                      how='outer', on='tmp').drop('tmp', axis=1)

# Combine the parts of speech
cross_product['pos_list'] = cross_product.apply(lambda row: (row['pos'], *row['pos_list']), axis=1)

# Add new probability to old
cross_product['score'] += cross_product['lexical_log_probs'] + \
                          cross_product['pos_list'].apply(compute_contextual_log_probability)

# Throw away the log prob columns we no longer need
partial_sequences = cross_product[['score', 'pos_list']].reset_index(drop=True)
print(partial_sequences)
# Out:
#          score              pos_list
# 0   -20.278554       (NPS, VB, PPSS)
# 1   -16.366531     (TO-HL, VB, PPSS)
# 2   -17.713605     (TO-NC, VB, PPSS)
# 3   -17.793647     (IN-TL, VB, PPSS)
# 4   -20.278554        (QL, VB, PPSS)
# 5   -19.179942       (NIL, VB, PPSS)
# 6   -18.199112     (IN-NC, VB, PPSS)
# 7    -7.739942        (TO, VB, PPSS)
# 8   -10.981761        (IN, VB, PPSS)
# 9   -16.151420     (IN-HL, VB, PPSS)
# 10  -21.810030       (NPS, UH, PPSS)
# 11  -17.898007     (TO-HL, UH, PPSS)
# 12  -19.245081     (TO-NC, UH, PPSS)
# 13  -19.325124     (IN-TL, UH, PPSS)
# 14  -21.810030        (QL, UH, PPSS)
# 15  -20.711418       (NIL, UH, PPSS)
# 16  -19.730589     (IN-NC, UH, PPSS)
# 17  -12.215857        (TO, UH, PPSS)
# 18  -12.513237        (IN, UH, PPSS)
# 19  -17.682896     (IN-HL, UH, PPSS)
# 20  -21.534489    (NPS, VB, PPSS-HL)
# 21  -17.622466  (TO-HL, VB, PPSS-HL)
# 22  -18.969540  (TO-NC, VB, PPSS-HL)
# 23  -19.049583  (IN-TL, VB, PPSS-HL)
# 24  -21.534489     (QL, VB, PPSS-HL)
# 25  -20.435877    (NIL, VB, PPSS-HL)
# 26  -19.455048  (IN-NC, VB, PPSS-HL)
# 27  -11.940316     (TO, VB, PPSS-HL)
# 28  -12.237696     (IN, VB, PPSS-HL)
# 29  -17.407355  (IN-HL, VB, PPSS-HL)
# ..         ...                   ...
# 90  -20.724160     (NPS, UH, PPO-NC)
# 91  -16.812137   (TO-HL, UH, PPO-NC)
# 92  -18.159210   (TO-NC, UH, PPO-NC)
# 93  -18.239253   (IN-TL, UH, PPO-NC)
# 94  -20.724160      (QL, UH, PPO-NC)
# 95  -19.625548     (NIL, UH, PPO-NC)
# 96  -18.644718   (IN-NC, UH, PPO-NC)
# 97  -11.129987      (TO, UH, PPO-NC)
# 98  -11.427367      (IN, UH, PPO-NC)
# 99  -16.597025   (IN-HL, UH, PPO-NC)
# 100 -19.796218    (NPS, VB, PPSS-NC)
# 101 -15.884195  (TO-HL, VB, PPSS-NC)
# 102 -17.231269  (TO-NC, VB, PPSS-NC)
# 103 -17.311312  (IN-TL, VB, PPSS-NC)
# 104 -19.796218     (QL, VB, PPSS-NC)
# 105 -18.697606    (NIL, VB, PPSS-NC)
# 106 -17.716777  (IN-NC, VB, PPSS-NC)
# 107 -10.202045     (TO, VB, PPSS-NC)
# 108 -10.499425     (IN, VB, PPSS-NC)
# 109 -15.669084  (IN-HL, VB, PPSS-NC)
# 110 -21.327695    (NPS, UH, PPSS-NC)
# 111 -17.415672  (TO-HL, UH, PPSS-NC)
# 112 -18.762745  (TO-NC, UH, PPSS-NC)
# 113 -18.842788  (IN-TL, UH, PPSS-NC)
# 114 -21.327695     (QL, UH, PPSS-NC)
# 115 -20.229083    (NIL, UH, PPSS-NC)
# 116 -19.248253  (IN-NC, UH, PPSS-NC)
# 117 -11.733522     (TO, UH, PPSS-NC)
# 118 -12.030902     (IN, UH, PPSS-NC)
# 119 -17.200560  (IN-HL, UH, PPSS-NC)
#
# [120 rows x 2 columns]

# %% [markdown]
# The next word of our sentence is 'tried'.

# %%
# Get all assignments of parts of speech to 'tried', and their lexical log probabilities
tried_assignments = pos_frequencies[pos_frequencies.word == 'tried'][['lexical_log_probs', 'pos']]

# Compute the cross product (all combinations) of the two series of parts of speech,
# to generate all part of speech assignments for the four-word sequence 'tried to please you'
cross_product = partial_sequences.assign(tmp=1).merge(tried_assignments.assign(tmp=1),
                                                      how='outer', on='tmp').drop('tmp', axis=1)

# Combine the parts of speech
cross_product['pos_list'] = cross_product.apply(lambda row: (row['pos'], *row['pos_list']), axis=1)

# Add new probability to old
cross_product['score'] += cross_product['lexical_log_probs'] + \
                          cross_product['pos_list'].apply(compute_contextual_log_probability)

# Throw away the log prob columns we no longer need
partial_sequences = cross_product[['score', 'pos_list']].reset_index(drop=True)
print(partial_sequences)
# Out:
#          score                   pos_list
# 0   -24.983569       (VBN, NPS, VB, PPSS)
# 1   -24.801248       (VBD, NPS, VB, PPSS)
# 2   -17.590306     (VBN, TO-HL, VB, PPSS)
# 3   -16.714838     (VBD, TO-HL, VB, PPSS)
# 4   -18.937380     (VBN, TO-NC, VB, PPSS)
# 5   -18.061911     (VBD, TO-NC, VB, PPSS)
# 6   -19.017423     (VBN, IN-TL, VB, PPSS)
# 7   -18.141954     (VBD, IN-TL, VB, PPSS)
# 8   -23.294089        (VBN, QL, VB, PPSS)
# 9   -22.418620        (VBD, QL, VB, PPSS)
# 10  -20.403717       (VBN, NIL, VB, PPSS)
# 11  -19.528248       (VBD, NIL, VB, PPSS)
# 12  -19.422888     (VBN, IN-NC, VB, PPSS)
# 13  -18.547419     (VBD, IN-NC, VB, PPSS)
# 14  -11.236804        (VBN, TO, VB, PPSS)
# 15  -10.612311        (VBD, TO, VB, PPSS)
# 16  -14.556911        (VBN, IN, VB, PPSS)
# 17  -14.374590        (VBD, IN, VB, PPSS)
# 18  -17.375195     (VBN, IN-HL, VB, PPSS)
# 19  -16.499726     (VBD, IN-HL, VB, PPSS)
# 20  -23.033806       (VBN, NPS, UH, PPSS)
# 21  -22.158337       (VBD, NPS, UH, PPSS)
# 22  -19.121783     (VBN, TO-HL, UH, PPSS)
# 23  -18.246314     (VBD, TO-HL, UH, PPSS)
# 24  -20.468856     (VBN, TO-NC, UH, PPSS)
# 25  -19.593388     (VBD, TO-NC, UH, PPSS)
# 26  -20.548899     (VBN, IN-TL, UH, PPSS)
# 27  -19.673430     (VBD, IN-TL, UH, PPSS)
# 28  -23.033806        (VBN, QL, UH, PPSS)
# 29  -22.158337        (VBD, QL, UH, PPSS)
# ..         ...                        ...
# 210 -19.921382    (VBN, NIL, VB, PPSS-NC)
# 211 -19.045913    (VBD, NIL, VB, PPSS-NC)
# 212 -18.940552  (VBN, IN-NC, VB, PPSS-NC)
# 213 -18.065084  (VBD, IN-NC, VB, PPSS-NC)
# 214 -13.698907     (VBN, TO, VB, PPSS-NC)
# 215 -13.074414     (VBD, TO, VB, PPSS-NC)
# 216 -14.074576     (VBN, IN, VB, PPSS-NC)
# 217 -13.892254     (VBD, IN, VB, PPSS-NC)
# 218 -16.892860  (VBN, IN-HL, VB, PPSS-NC)
# 219 -16.017391  (VBD, IN-HL, VB, PPSS-NC)
# 220 -22.551470    (VBN, NPS, UH, PPSS-NC)
# 221 -21.676002    (VBD, NPS, UH, PPSS-NC)
# 222 -18.639447  (VBN, TO-HL, UH, PPSS-NC)
# 223 -17.763979  (VBD, TO-HL, UH, PPSS-NC)
# 224 -19.986521  (VBN, TO-NC, UH, PPSS-NC)
# 225 -19.111052  (VBD, TO-NC, UH, PPSS-NC)
# 226 -20.066564  (VBN, IN-TL, UH, PPSS-NC)
# 227 -19.191095  (VBD, IN-TL, UH, PPSS-NC)
# 228 -22.551470     (VBN, QL, UH, PPSS-NC)
# 229 -21.676002     (VBD, QL, UH, PPSS-NC)
# 230 -21.452858    (VBN, NIL, UH, PPSS-NC)
# 231 -20.577389    (VBD, NIL, UH, PPSS-NC)
# 232 -20.472029  (VBN, IN-NC, UH, PPSS-NC)
# 233 -19.596560  (VBD, IN-NC, UH, PPSS-NC)
# 234 -12.957297     (VBN, TO, UH, PPSS-NC)
# 235 -12.081828     (VBD, TO, UH, PPSS-NC)
# 236 -14.864115     (VBN, IN, UH, PPSS-NC)
# 237 -13.988646     (VBD, IN, UH, PPSS-NC)
# 238 -18.424336  (VBN, IN-HL, UH, PPSS-NC)
# 239 -17.548867  (VBD, IN-HL, UH, PPSS-NC)
#
# [240 rows x 2 columns]

# %% [markdown]
# The number of partial sequences is blowing up exponentially. Luckily, we have reached the limit of our three-tag window, and can now remove paths.

# %%
def filter_out_sequences(partial_sequences):
    
    # Get the two front parts of speech
    partial_sequences['two_most_recent_pos'] = partial_sequences['pos_list'].apply(lambda l: l[:2])
    #print(partial_sequences)

    # Grouping by the two front parts of speech, find the rows with the maximum score for each group
    keep_idx = partial_sequences.groupby('two_most_recent_pos')['score'].idxmax().values
    #print(keep_idx)

    # Filter and keep only those rows
    partial_sequences = partial_sequences.loc[keep_idx]
    #print(partial_sequences)

    partial_sequences = partial_sequences[['score', 'pos_list']].reset_index(drop=True)
    return partial_sequences

partial_sequences = filter_out_sequences(partial_sequences)
print(partial_sequences)
# Out:
#         score                  pos_list
# 0  -13.288719     (VBD, IN, VB, PPO-NC)
# 1  -15.413856  (VBD, IN-HL, VB, PPO-NC)
# 2  -17.461549  (VBD, IN-NC, VB, PPO-NC)
# 3  -17.056083  (VBD, IN-TL, VB, PPO-NC)
# 4  -18.442378    (VBD, NIL, VB, PPO-NC)
# 5  -21.072467    (VBD, NPS, UH, PPO-NC)
# 6  -21.072467     (VBD, QL, UH, PPO-NC)
# 7   -7.157035        (VBD, TO, VB, PPO)
# 8  -15.628967  (VBD, TO-HL, VB, PPO-NC)
# 9  -16.976041  (VBD, TO-NC, VB, PPO-NC)
# 10 -13.471041     (VBN, IN, VB, PPO-NC)
# 11 -16.289325  (VBN, IN-HL, VB, PPO-NC)
# 12 -18.337017  (VBN, IN-NC, VB, PPO-NC)
# 13 -17.931552  (VBN, IN-TL, VB, PPO-NC)
# 14 -19.317847    (VBN, NIL, VB, PPO-NC)
# 15 -21.947935    (VBN, NPS, UH, PPO-NC)
# 16 -21.947935     (VBN, QL, UH, PPO-NC)
# 17  -7.781528        (VBN, TO, VB, PPO)
# 18 -16.504436  (VBN, TO-HL, VB, PPO-NC)
# 19 -17.851510  (VBN, TO-NC, VB, PPO-NC)

# %% [markdown]
# Ok, now the list is much shorter! Let's keep going. The next and final word of our sentence is 'I'.

# %%
# Get all assignments of parts of speech to 'I', and their lexical log probabilities
I_assignments = pos_frequencies[pos_frequencies.word == 'I'][['lexical_log_probs', 'pos']]

# Compute the cross product (all combinations) of the two series of parts of speech,
# to generate all part of speech assignments for the four-word sequence 'I tried to please you'
cross_product = partial_sequences.assign(tmp=1).merge(I_assignments.assign(tmp=1),
                                                      how='outer', on='tmp').drop('tmp', axis=1)

# Combine the parts of speech
cross_product['pos_list'] = cross_product.apply(lambda row: (row['pos'], *row['pos_list']), axis=1)

# Add new probability to old
cross_product['score'] += cross_product['lexical_log_probs'] + \
                          cross_product['pos_list'].apply(compute_contextual_log_probability)

# Throw away the log prob columns we no longer need
partial_sequences = cross_product[['score', 'pos_list']].reset_index(drop=True)
print(partial_sequences)
# Out:
#          score                           pos_list
# 0   -23.961374          (NP, VBD, IN, VB, PPO-NC)
# 1   -29.529718     (PPSS-HL, VBD, IN, VB, PPO-NC)
# 2   -30.222865         (NIL, VBD, IN, VB, PPO-NC)
# 3   -26.111992       (NN-TL, VBD, IN, VB, PPO-NC)
# 4   -15.577641        (PPSS, VBD, IN, VB, PPO-NC)
# 5   -22.653454          (NN, VBD, IN, VB, PPO-NC)
# 6   -27.044812     (PPSS-NC, VBD, IN, VB, PPO-NC)
# 7   -23.962741       (NP, VBD, IN-HL, VB, PPO-NC)
# 8   -23.269594  (PPSS-HL, VBD, IN-HL, VB, PPO-NC)
# 9   -23.962741      (NIL, VBD, IN-HL, VB, PPO-NC)
# 10  -23.962741    (NN-TL, VBD, IN-HL, VB, PPO-NC)
# 11  -15.420075     (PPSS, VBD, IN-HL, VB, PPO-NC)
# 12  -22.864129       (NN, VBD, IN-HL, VB, PPO-NC)
# 13  -20.784688  (PPSS-NC, VBD, IN-HL, VB, PPO-NC)
# 14  -26.010434       (NP, VBD, IN-NC, VB, PPO-NC)
# 15  -25.317287  (PPSS-HL, VBD, IN-NC, VB, PPO-NC)
# 16  -26.010434      (NIL, VBD, IN-NC, VB, PPO-NC)
# 17  -26.010434    (NN-TL, VBD, IN-NC, VB, PPO-NC)
# 18  -17.467768     (PPSS, VBD, IN-NC, VB, PPO-NC)
# 19  -24.911822       (NN, VBD, IN-NC, VB, PPO-NC)
# 20  -22.832380  (PPSS-NC, VBD, IN-NC, VB, PPO-NC)
# 21  -25.604969       (NP, VBD, IN-TL, VB, PPO-NC)
# 22  -24.911822  (PPSS-HL, VBD, IN-TL, VB, PPO-NC)
# 23  -25.604969      (NIL, VBD, IN-TL, VB, PPO-NC)
# 24  -25.604969    (NN-TL, VBD, IN-TL, VB, PPO-NC)
# 25  -17.062303     (PPSS, VBD, IN-TL, VB, PPO-NC)
# 26  -24.506357       (NN, VBD, IN-TL, VB, PPO-NC)
# 27  -22.426915  (PPSS-NC, VBD, IN-TL, VB, PPO-NC)
# 28  -26.991263         (NP, VBD, NIL, VB, PPO-NC)
# 29  -26.298116    (PPSS-HL, VBD, NIL, VB, PPO-NC)
# ..         ...                                ...
# 110 -31.344119         (NN, VBN, NPS, UH, PPO-NC)
# 111 -29.957824    (PPSS-NC, VBN, NPS, UH, PPO-NC)
# 112 -35.960653          (NP, VBN, QL, UH, PPO-NC)
# 113 -35.267506     (PPSS-HL, VBN, QL, UH, PPO-NC)
# 114 -35.960653         (NIL, VBN, QL, UH, PPO-NC)
# 115 -35.960653       (NN-TL, VBN, QL, UH, PPO-NC)
# 116 -26.724840        (PPSS, VBN, QL, UH, PPO-NC)
# 117 -32.377134          (NN, VBN, QL, UH, PPO-NC)
# 118 -32.782599     (PPSS-NC, VBN, QL, UH, PPO-NC)
# 119 -22.571339             (NP, VBN, TO, VB, PPO)
# 120 -22.976804        (PPSS-HL, VBN, TO, VB, PPO)
# 121 -23.669951            (NIL, VBN, TO, VB, PPO)
# 122 -22.976804          (NN-TL, VBN, TO, VB, PPO)
# 123 -15.127285           (PPSS, VBN, TO, VB, PPO)
# 124 -18.428204             (NN, VBN, TO, VB, PPO)
# 125 -20.491897        (PPSS-NC, VBN, TO, VB, PPO)
# 126 -25.053322       (NP, VBN, TO-HL, VB, PPO-NC)
# 127 -24.360174  (PPSS-HL, VBN, TO-HL, VB, PPO-NC)
# 128 -25.053322      (NIL, VBN, TO-HL, VB, PPO-NC)
# 129 -25.053322    (NN-TL, VBN, TO-HL, VB, PPO-NC)
# 130 -16.510656     (PPSS, VBN, TO-HL, VB, PPO-NC)
# 131 -23.954709       (NN, VBN, TO-HL, VB, PPO-NC)
# 132 -21.875268  (PPSS-NC, VBN, TO-HL, VB, PPO-NC)
# 133 -26.400395       (NP, VBN, TO-NC, VB, PPO-NC)
# 134 -25.707248  (PPSS-HL, VBN, TO-NC, VB, PPO-NC)
# 135 -26.400395      (NIL, VBN, TO-NC, VB, PPO-NC)
# 136 -26.400395    (NN-TL, VBN, TO-NC, VB, PPO-NC)
# 137 -17.857729     (PPSS, VBN, TO-NC, VB, PPO-NC)
# 138 -25.301783       (NN, VBN, TO-NC, VB, PPO-NC)
# 139 -23.222341  (PPSS-NC, VBN, TO-NC, VB, PPO-NC)
#
# [140 rows x 2 columns]

# %% [markdown]
# Once again, filter out assignments which score less than some other path in their window group.

# %%
partial_sequences = filter_out_sequences(partial_sequences)
print(partial_sequences)
# Out:
#         score                     pos_list
# 0  -22.812527      (NIL, VBD, TO, VB, PPO)
# 1  -23.669951      (NIL, VBN, TO, VB, PPO)
# 2  -16.779441       (NN, VBD, TO, VB, PPO)
# 3  -18.428204       (NN, VBN, TO, VB, PPO)
# 4  -19.979314    (NN-TL, VBD, TO, VB, PPO)
# 5  -22.976804    (NN-TL, VBN, TO, VB, PPO)
# 6  -17.870884       (NP, VBD, TO, VB, PPO)
# 7  -22.571339       (NP, VBN, TO, VB, PPO)
# 8   -9.176111     (PPSS, VBD, TO, VB, PPO)
# 9  -15.127285     (PPSS, VBN, TO, VB, PPO)
# 10 -22.119380  (PPSS-HL, VBD, TO, VB, PPO)
# 11 -22.976804  (PPSS-HL, VBN, TO, VB, PPO)
# 12 -19.634473  (PPSS-NC, VBD, TO, VB, PPO)
# 13 -20.491897  (PPSS-NC, VBN, TO, VB, PPO)

# %% [markdown]
# Now just continue with a couple of blank parts of speech for the words out of range. The lexical probability of a word out of range should be 1, i.e. should not affect the scores. However the look-ahead contextual probability could still change the scores based on which parts of speech are most likely to start a sentence. Earlier when computing the n-gram tables, I made some simple assumptions using a period '.' part-of-speech, which is in the tagged corpus, as a start symbol. This gives us an estimate of the contextual probabilities that we can use now.

# %%
# No need to compute a cross-product, since there is only one possible part of speech for a word out of range: ''
# Prepend a blank part-of-speech to all the part of speech sequences
partial_sequences['pos_list'] = partial_sequences.apply(lambda row: ('', *row['pos_list']), axis=1)

# Add contextual log probabilities to old
partial_sequences['score'] += partial_sequences['pos_list'].apply(compute_contextual_log_probability)

#print(partial_sequences)

# Filter out bad paths
partial_sequences = filter_out_sequences(partial_sequences)
print(partial_sequences)
# Out:
#         score                       pos_list
# 0  -22.812527      (, NIL, VBD, TO, VB, PPO)
# 1  -23.669951      (, NIL, VBN, TO, VB, PPO)
# 2  -20.606571       (, NN, VBD, TO, VB, PPO)
# 3  -22.967353       (, NN, VBN, TO, VB, PPO)
# 4  -22.682413    (, NN-TL, VBD, TO, VB, PPO)
# 5  -26.112298    (, NN-TL, VBN, TO, VB, PPO)
# 6  -19.002156       (, NP, VBD, TO, VB, PPO)
# 7  -24.197306       (, NP, VBN, TO, VB, PPO)
# 8  -10.379500     (, PPSS, VBD, TO, VB, PPO)
# 9  -18.494581     (, PPSS, VBN, TO, VB, PPO)
# 10 -22.119380  (, PPSS-HL, VBD, TO, VB, PPO)
# 11 -22.976804  (, PPSS-HL, VBN, TO, VB, PPO)
# 12 -19.634473  (, PPSS-NC, VBD, TO, VB, PPO)
# 13 -20.491897  (, PPSS-NC, VBN, TO, VB, PPO)
#        score                       pos_list
# 0 -22.812527      (, NIL, VBD, TO, VB, PPO)
# 1 -20.606571       (, NN, VBD, TO, VB, PPO)
# 2 -22.682413    (, NN-TL, VBD, TO, VB, PPO)
# 3 -19.002156       (, NP, VBD, TO, VB, PPO)
# 4 -10.379500     (, PPSS, VBD, TO, VB, PPO)
# 5 -22.119380  (, PPSS-HL, VBD, TO, VB, PPO)
# 6 -19.634473  (, PPSS-NC, VBD, TO, VB, PPO)

# %% [markdown]
# Once more.

# %%
# No need to compute a cross-product, since there is only one possible part of speech for a word out of range: ''
# Prepend a blank part-of-speech to all the part of speech sequences
partial_sequences['pos_list'] = partial_sequences.apply(lambda row: ('', *row['pos_list']), axis=1)

# Add contextual log probabilities to old
partial_sequences['score'] += partial_sequences['pos_list'].apply(compute_contextual_log_probability)

#print(partial_sequences)

# Filter out bad paths
partial_sequences = filter_out_sequences(partial_sequences)
print(partial_sequences)
# Out:
#      score                      pos_list
# 0 -10.3795  (, , PPSS, VBD, TO, VB, PPO)

# %% [markdown]
# And at long last, there we go. The optimal assignment is: I/PPSS tried/VBD to/TO please/VB you/PPO
#
# I hope this in-depth answer pleases you.
